# %%
import pandas as pd

# %% [markdown]
# # Create DataFrame

# %%
# pd.Series(data,index,dtype)
pd.Series([10,20,30])
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %% [markdown]
# # pd.DataFrame(data,index,columns,dtype)

# %%
pd.DataFrame([10,20,30])
# Out:
#     0
# 0  10
# 1  20
# 2  30

# %%
# empty
print(pd.DataFrame())
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.DataFrame?

# %%
import numpy as np
a = np.random.random((4,4))
a
# Out:
# array([[0.29258861, 0.33544914, 0.65631055, 0.21416737],
#        [0.13892526, 0.64408084, 0.21246248, 0.08713024],
#        [0.25862937, 0.9268605 , 0.3564794 , 0.97884554],
#        [0.87253609, 0.20328194, 0.4094407 , 0.74063222]])

# %%
pd.DataFrame(a)
# Out:
#           0         1         2         3
# 0  0.292589  0.335449  0.656311  0.214167
# 1  0.138925  0.644081  0.212462  0.087130
# 2  0.258629  0.926861  0.356479  0.978846
# 3  0.872536  0.203282  0.409441  0.740632

# %%
d1 = pd.DataFrame(a, columns = ['val_1','val_2','val_3','val_4'], index=['poonam','kushal','abhishek','shruti'])
d1
# Out:
#              val_1     val_2     val_3     val_4
# poonam    0.292589  0.335449  0.656311  0.214167
# kushal    0.138925  0.644081  0.212462  0.087130
# abhishek  0.258629  0.926861  0.356479  0.978846
# shruti    0.872536  0.203282  0.409441  0.740632

# %%
# 100 vs [100] ?     ===   int and list
pd.DataFrame(data=[100])
# Out:
#      0
# 0  100

# %%
s = pd.Series(range(2,12))
s
# Out:
# 0     2
# 1     3
# 2     4
# 3     5
# 4     6
# 5     7
# 6     8
# 7     9
# 8    10
# 9    11
# dtype: int64

# %%
pd.DataFrame(s,columns = ['data'])
# Out:
#    data
# 0     2
# 1     3
# 2     4
# 3     5
# 4     6
# 5     7
# 6     8
# 7     9
# 8    10
# 9    11

# %%
# fetch elements of specific index
pd.Series(s,index=[0,5,7])
# Out:
# 0    2
# 5    7
# 7    9
# dtype: int64

# %%
rh = [5,1,7,4,2]
pd.Series(s,index = rh)
# Out:
# 5    7
# 1    3
# 7    9
# 4    6
# 2    4
# dtype: int64

# %%
rh = [15,1,7,4,2]
pd.Series(s,index = rh)
# Out:
# 15    NaN
# 1     3.0
# 7     9.0
# 4     6.0
# 2     4.0
# dtype: float64

# %%
rh = [7,1,7,4,2]   # multiple indexing is also allowed
pd.Series(s,index = rh)
# Out:
# 7    9
# 1    3
# 7    9
# 4    6
# 2    4
# dtype: int64

# %%
pd.DataFrame([10,20,30,40],index = [120,121,123,124],columns=['column1'])
# Out:
#      column1
# 120       10
# 121       20
# 123       30
# 124       40

# %%
pd.DataFrame([10,20,30,40],index = [120,121,123,124],columns=['column1']).T
# Out:
#          120  121  123  124
# column1   10   20   30   40

# %%
pd.DataFrame([10,20,30,40],index = [120,121,123,124],columns=['column1']).mean()
# Out:
# column1    25.0
# dtype: float64

# %%
# we can also create a df using dict with multiple values
emp = {'name':['Dhanashri','Ani','Kanchan'],
       'post':['SD','DS','HR'],
       }
emp
# Out:
# {'name': ['Dhanashri', 'Ani', 'Kanchan'], 'post': ['SD', 'DS', 'HR']}

# %%
pd.DataFrame(emp)
# Out:
#         name post
# 0  Dhanashri   SD
# 1        Ani   DS
# 2    Kanchan   HR

# %%
d = {1:100, 2:200, 3:300}
d
# Out:
# {1: 100, 2: 200, 3: 300}

# %%
pd.DataFrame(d) # why error?
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-3449b472dc69> in <cell line: 1>()
# ----> 1 pd.DataFrame(d)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     662         elif isinstance(data, dict):
#     663             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665         elif isinstance(data, ma.MaskedArray):
#     666             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     491             arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
#     492
# ...

# %%
pd.DataFrame(d,index=[0])
# Out:
#      1    2    3
# 0  100  200  300

# %%
d = {1:[100],2:[200],3:[300]}
d
# Out:
# {1: [100], 2: [200], 3: [300]}

# %%
pd.DataFrame(d)
# Out:
#      1    2    3
# 0  100  200  300

# %%
# Dataframe using dict of series
pd.DataFrame({'A':pd.Series([100,200,300]),
              'B':pd.Series([300,400,500])})
# Out:
#      A    B
# 0  100  300
# 1  200  400
# 2  300  500

# %%
pd.DataFrame({'shital':range(1,6),'ashish':np.arange(100,105)})
# Out:
#    shital  ashish
# 0       1     100
# 1       2     101
# 2       3     102
# 3       4     103
# 4       5     104

# %% [markdown]
# # Lets check properties of dataframe

# %%
d1
# Out:
#              val_1     val_2     val_3     val_4
# poonam    0.292589  0.335449  0.656311  0.214167
# kushal    0.138925  0.644081  0.212462  0.087130
# abhishek  0.258629  0.926861  0.356479  0.978846
# shruti    0.872536  0.203282  0.409441  0.740632

# %%
d1.shape
# Out:
# (4, 4)

# %%
d1.columns
# Out:
# Index(['val_1', 'val_2', 'val_3', 'val_4'], dtype='object')

# %%
d1.index
# Out:
# Index(['poonam', 'kushal', 'abhishek', 'shruti'], dtype='object')

# %%
d1.size
# Out:
# 16

# %%
d1.shape[0]
# Out:
# 4

# %%
len(d1)
# Out:
# 4

# %%
df = pd.DataFrame({'name':['rupali','amol','jyoti','sneha','akshay'],
                   'place':['pune','kolhapur','sangli','kudal','satara'],
                   'team':['mi','csk','rcb','gt','rr']})
df
# Out:
#      name     place team
# 0  rupali      pune   mi
# 1    amol  kolhapur  csk
# 2   jyoti    sangli  rcb
# 3   sneha     kudal   gt
# 4  akshay    satara   rr

# %%
df['place'] # 1D series
# Out:
# 0        pune
# 1    kolhapur
# 2      sangli
# 3       kudal
# 4      satara
# Name: place, dtype: object

# %%
df[['place']] # 2D
# Out:
#       place
# 0      pune
# 1  kolhapur
# 2    sangli
# 3     kudal
# 4    satara

# %%
df.place
# Out:
# 0        pune
# 1    kolhapur
# 2      sangli
# 3       kudal
# 4      satara
# Name: place, dtype: object

# %%
df[['name','team']]
# Out:
#      name team
# 0  rupali   mi
# 1    amol  csk
# 2   jyoti  rcb
# 3   sneha   gt
# 4  akshay   rr

# %%
df.columns
# Out:
# Index(['name', 'place', 'team'], dtype='object')

# %%
df[['team','place']]
# Out:
#   team     place
# 0   mi      pune
# 1  csk  kolhapur
# 2  rcb    sangli
# 3   gt     kudal
# 4   rr    satara

# %%
df
# Out:
#      name     place team
# 0  rupali      pune   mi
# 1    amol  kolhapur  csk
# 2   jyoti    sangli  rcb
# 3   sneha     kudal   gt
# 4  akshay    satara   rr

# %%
'sam 'LIVE''         # not allowed
'sam "LIVE"'         # allowed

# %%
# select data whose place is pune
df.query('place=="pune"')
# Out:
#      name place team
# 0  rupali  pune   mi

# %%
df.query('team=="csk"')
# Out:
#    name     place team
# 1  amol  kolhapur  csk

# %%
df
# Out:
#      name     place team
# 0  rupali      pune   mi
# 1    amol  kolhapur  csk
# 2   jyoti    sangli  rcb
# 3   sneha     kudal   gt
# 4  akshay    satara   rr

# %%
# fetch team gt and place kudal
df.query('place=="kudal" and team=="gt"')
# Out:
#     name  place team
# 3  sneha  kudal   gt

# %%
# place ending with i
df.place.str.endswith('i')
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: place, dtype: bool

# %%
df.name.str.endswith('i')
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# Name: name, dtype: bool

# %%
# use boolean output as an index
df[df.name.str.endswith('i')]
# Out:
#      name   place team
# 0  rupali    pune   mi
# 2   jyoti  sangli  rcb

# %%
df[df.name.apply(lambda nm:nm.endswith('i'))]
# Out:
#      name   place team
# 0  rupali    pune   mi
# 2   jyoti  sangli  rcb

# %%
len('')

# %%
df.place.apply(len) >= 6
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4     True
# Name: place, dtype: bool

# %%
df[df.place.apply(len) >= 6]
# Out:
#      name     place team
# 1    amol  kolhapur  csk
# 2   jyoti    sangli  rcb
# 4  akshay    satara   rr

# %%
# place with minimum length
df.place.apply(len).min()
# Out:
# 4

# %%
df[df.place.apply(len) == 4]
# Out:
#      name place team
# 0  rupali  pune   mi

# %%
# can apply query on numbers?
a = pd.DataFrame(a)
a
# Out:
#           0         1         2         3
# 0  0.292589  0.335449  0.656311  0.214167
# 1  0.138925  0.644081  0.212462  0.087130
# 2  0.258629  0.926861  0.356479  0.978846
# 3  0.872536  0.203282  0.409441  0.740632

# %%
a.columns
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
# entries from col 1 > 0.6
a.query('1>0.6')
# query needs an expression in str
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-d5a29e217e06> in <cell line: 2>()
#       1 # entries from col 1 > 0.6
# ----> 2 a.query('1>0.6')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    4475
#    4476         try:
# -> 4477             result = self.loc[res]
#    4478         except ValueError:
#    4479             # when res is multi-dimensional loc raises, but this is sometimes a
#
# ...

# %%
# convert col labels into str
a.columns = ['p','q','r','s']
a
# Out:
#           p         q         r         s
# 0  0.292589  0.335449  0.656311  0.214167
# 1  0.138925  0.644081  0.212462  0.087130
# 2  0.258629  0.926861  0.356479  0.978846
# 3  0.872536  0.203282  0.409441  0.740632

# %%
a.query('q > 0.6')
# Out:
#           p         q         r         s
# 1  0.138925  0.644081  0.212462  0.087130
# 2  0.258629  0.926861  0.356479  0.978846
